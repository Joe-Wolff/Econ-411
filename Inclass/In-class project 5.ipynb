# %% [markdown]
# ## Chapter 4

# %% [markdown]
# ## Total
# # $\sum{i=0}^{n-1}x_{i}$

# %%
n =0 
total=0
i =0
values = [i for i in range(10)]
print("total\t","value")
for value in values:
    total += value
    print(total,"\t",value)
    
print("final total:",total)
# Out:
# total	 value
# 0 	 0
# 1 	 1
# 3 	 2
# 6 	 3
# 10 	 4
# 15 	 5
# 21 	 6
# 28 	 7
# 36 	 8
# 45 	 9
# final total: 45

# %%
n =0 
total=0
i =0
values = [i for i in range(100)]
print("total\t","value")
for value in values:
    total += value
    print(total,"\t",value)
    
print("final total:",total)
# Out:
# total	 value
# 0 	 0
# 1 	 1
# 3 	 2
# 6 	 3
# 10 	 4
# 15 	 5
# 21 	 6
# 28 	 7
# 36 	 8
# 45 	 9
# 55 	 10
# 66 	 11
# 78 	 12
# 91 	 13
# 105 	 14
# 120 	 15
# 136 	 16
# 153 	 17
# 171 	 18
# 190 	 19
# 210 	 20
# 231 	 21
# 253 	 22
# 276 	 23
# 300 	 24
# 325 	 25
# 351 	 26
# 378 	 27
# 406 	 28
# 435 	 29
# 465 	 30
# 496 	 31
# 528 	 32
# 561 	 33
# 595 	 34
# 630 	 35
# 666 	 36
# 703 	 37
# 741 	 38
# 780 	 39
# 820 	 40
# 861 	 41
# 903 	 42
# 946 	 43
# 990 	 44
# 1035 	 45
# 1081 	 46
# 1128 	 47
# 1176 	 48
# 1225 	 49
# 1275 	 50
# 1326 	 51
# 1378 	 52
# 1431 	 53
# 1485 	 54
# 1540 	 55
# 1596 	 56
# 1653 	 57
# 1711 	 58
# 1770 	 59
# 1830 	 60
# 1891 	 61
# 1953 	 62
# 2016 	 63
# 2080 	 64
# 2145 	 65
# 2211 	 66
# 2278 	 67
# 2346 	 68
# 2415 	 69
# 2485 	 70
# 2556 	 71
# 2628 	 72
# 2701 	 73
# 2775 	 74
# 2850 	 75
# 2926 	 76
# 3003 	 77
# 3081 	 78
# 3160 	 79
# 3240 	 80
# 3321 	 81
# 3403 	 82
# 3486 	 83
# 3570 	 84
# 3655 	 85
# 3741 	 86
# 3828 	 87
# 3916 	 88
# 4005 	 89
# 4095 	 90
# 4186 	 91
# 4278 	 92
# 4371 	 93
# 4465 	 94
# 4560 	 95
# 4656 	 96
# 4753 	 97
# 4851 	 98
# 4950 	 99
# final total: 4950

# %%
n =0 
total=0
i =0
values = [i for i in range(0,1000,2)]
print("total\t","value")
for value in values:
    total += value
    print(total,"\t",value)
    
print("final total:",total)
# Out:
# total	 value
# 0 	 0
# 2 	 2
# 6 	 4
# 12 	 6
# 20 	 8
# 30 	 10
# 42 	 12
# 56 	 14
# 72 	 16
# 90 	 18
# 110 	 20
# 132 	 22
# 156 	 24
# 182 	 26
# 210 	 28
# 240 	 30
# 272 	 32
# 306 	 34
# 342 	 36
# 380 	 38
# 420 	 40
# 462 	 42
# 506 	 44
# 552 	 46
# 600 	 48
# 650 	 50
# 702 	 52
# 756 	 54
# 812 	 56
# 870 	 58
# 930 	 60
# 992 	 62
# 1056 	 64
# 1122 	 66
# 1190 	 68
# 1260 	 70
# 1332 	 72
# 1406 	 74
# 1482 	 76
# 1560 	 78
# 1640 	 80
# 1722 	 82
# 1806 	 84
# 1892 	 86
# 1980 	 88
# 2070 	 90
# 2162 	 92
# 2256 	 94
# 2352 	 96
# 2450 	 98
# 2550 	 100
# 2652 	 102
# 2756 	 104
# 2862 	 106
# 2970 	 108
# 3080 	 110
# 3192 	 112
# 3306 	 114
# 3422 	 116
# 3540 	 118
# 3660 	 120
# 3782 	 122
# 3906 	 124
# 4032 	 126
# 4160 	 128
# 4290 	 130
# 4422 	 132
# 4556 	 134
# 4692 	 136
# 4830 	 138
# 4970 	 140
# 5112 	 142
# 5256 	 144
# 5402 	 146
# 5550 	 148
# 5700 	 150
# 5852 	 152
# 6006 	 154
# 6162 	 156
# 6320 	 158
# 6480 	 160
# 6642 	 162
# 6806 	 164
# 6972 	 166
# 7140 	 168
# 7310 	 170
# 7482 	 172
# 7656 	 174
# 7832 	 176
# 8010 	 178
# 8190 	 180
# 8372 	 182
# 8556 	 184
# 8742 	 186
# 8930 	 188
# 9120 	 190
# 9312 	 192
# 9506 	 194
# 9702 	 196
# 9900 	 198
# 10100 	 200
# 10302 	 202
# 10506 	 204
# 10712 	 206
# 10920 	 208
# 11130 	 210
# 11342 	 212
# 11556 	 214
# 11772 	 216
# 11990 	 218
# 12210 	 220
# 12432 	 222
# 12656 	 224
# 12882 	 226
# 13110 	 228
# 13340 	 230
# 13572 	 232
# 13806 	 234
# 14042 	 236
# 14280 	 238
# 14520 	 240
# 14762 	 242
# 15006 	 244
# 15252 	 246
# 15500 	 248
# 15750 	 250
# 16002 	 252
# 16256 	 254
# 16512 	 256
# 16770 	 258
# 17030 	 260
# 17292 	 262
# 17556 	 264
# 17822 	 266
# 18090 	 268
# 18360 	 270
# 18632 	 272
# 18906 	 274
# 19182 	 276
# 19460 	 278
# 19740 	 280
# 20022 	 282
# 20306 	 284
# 20592 	 286
# 20880 	 288
# 21170 	 290
# 21462 	 292
# 21756 	 294
# 22052 	 296
# 22350 	 298
# 22650 	 300
# 22952 	 302
# 23256 	 304
# 23562 	 306
# 23870 	 308
# 24180 	 310
# 24492 	 312
# 24806 	 314
# 25122 	 316
# 25440 	 318
# 25760 	 320
# 26082 	 322
# 26406 	 324
# 26732 	 326
# 27060 	 328
# 27390 	 330
# 27722 	 332
# 28056 	 334
# 28392 	 336
# 28730 	 338
# 29070 	 340
# 29412 	 342
# 29756 	 344
# 30102 	 346
# 30450 	 348
# 30800 	 350
# 31152 	 352
# 31506 	 354
# 31862 	 356
# 32220 	 358
# 32580 	 360
# 32942 	 362
# 33306 	 364
# 33672 	 366
# 34040 	 368
# 34410 	 370
# 34782 	 372
# 35156 	 374
# 35532 	 376
# 35910 	 378
# 36290 	 380
# 36672 	 382
# 37056 	 384
# 37442 	 386
# 37830 	 388
# 38220 	 390
# 38612 	 392
# 39006 	 394
# 39402 	 396
# 39800 	 398
# 40200 	 400
# 40602 	 402
# 41006 	 404
# 41412 	 406
# 41820 	 408
# 42230 	 410
# 42642 	 412
# 43056 	 414
# 43472 	 416
# 43890 	 418
# 44310 	 420
# 44732 	 422
# 45156 	 424
# 45582 	 426
# 46010 	 428
# 46440 	 430
# 46872 	 432
# 47306 	 434
# 47742 	 436
# 48180 	 438
# 48620 	 440
# 49062 	 442
# 49506 	 444
# 49952 	 446
# 50400 	 448
# 50850 	 450
# 51302 	 452
# 51756 	 454
# 52212 	 456
# 52670 	 458
# 53130 	 460
# 53592 	 462
# 54056 	 464
# 54522 	 466
# 54990 	 468
# 55460 	 470
# 55932 	 472
# 56406 	 474
# 56882 	 476
# 57360 	 478
# 57840 	 480
# 58322 	 482
# 58806 	 484
# 59292 	 486
# 59780 	 488
# 60270 	 490
# 60762 	 492
# 61256 	 494
# 61752 	 496
# 62250 	 498
# 62750 	 500
# 63252 	 502
# 63756 	 504
# 64262 	 506
# 64770 	 508
# 65280 	 510
# 65792 	 512
# 66306 	 514
# 66822 	 516
# 67340 	 518
# 67860 	 520
# 68382 	 522
# 68906 	 524
# 69432 	 526
# 69960 	 528
# 70490 	 530
# 71022 	 532
# 71556 	 534
# 72092 	 536
# 72630 	 538
# 73170 	 540
# 73712 	 542
# 74256 	 544
# 74802 	 546
# 75350 	 548
# 75900 	 550
# 76452 	 552
# 77006 	 554
# 77562 	 556
# 78120 	 558
# 78680 	 560
# 79242 	 562
# 79806 	 564
# 80372 	 566
# 80940 	 568
# 81510 	 570
# 82082 	 572
# 82656 	 574
# 83232 	 576
# 83810 	 578
# 84390 	 580
# 84972 	 582
# 85556 	 584
# 86142 	 586
# 86730 	 588
# 87320 	 590
# 87912 	 592
# 88506 	 594
# 89102 	 596
# 89700 	 598
# 90300 	 600
# 90902 	 602
# 91506 	 604
# 92112 	 606
# 92720 	 608
# 93330 	 610
# 93942 	 612
# 94556 	 614
# 95172 	 616
# 95790 	 618
# 96410 	 620
# 97032 	 622
# 97656 	 624
# 98282 	 626
# 98910 	 628
# 99540 	 630
# 100172 	 632
# 100806 	 634
# 101442 	 636
# 102080 	 638
# 102720 	 640
# 103362 	 642
# 104006 	 644
# 104652 	 646
# 105300 	 648
# 105950 	 650
# 106602 	 652
# 107256 	 654
# 107912 	 656
# 108570 	 658
# 109230 	 660
# 109892 	 662
# 110556 	 664
# 111222 	 666
# 111890 	 668
# 112560 	 670
# 113232 	 672
# 113906 	 674
# 114582 	 676
# 115260 	 678
# 115940 	 680
# 116622 	 682
# 117306 	 684
# 117992 	 686
# 118680 	 688
# 119370 	 690
# 120062 	 692
# 120756 	 694
# 121452 	 696
# 122150 	 698
# 122850 	 700
# 123552 	 702
# 124256 	 704
# 124962 	 706
# 125670 	 708
# 126380 	 710
# 127092 	 712
# 127806 	 714
# 128522 	 716
# 129240 	 718
# 129960 	 720
# 130682 	 722
# 131406 	 724
# 132132 	 726
# 132860 	 728
# 133590 	 730
# 134322 	 732
# 135056 	 734
# 135792 	 736
# 136530 	 738
# 137270 	 740
# 138012 	 742
# 138756 	 744
# 139502 	 746
# 140250 	 748
# 141000 	 750
# 141752 	 752
# 142506 	 754
# 143262 	 756
# 144020 	 758
# 144780 	 760
# 145542 	 762
# 146306 	 764
# 147072 	 766
# 147840 	 768
# 148610 	 770
# 149382 	 772
# 150156 	 774
# 150932 	 776
# 151710 	 778
# 152490 	 780
# 153272 	 782
# 154056 	 784
# 154842 	 786
# 155630 	 788
# 156420 	 790
# 157212 	 792
# 158006 	 794
# 158802 	 796
# 159600 	 798
# 160400 	 800
# 161202 	 802
# 162006 	 804
# 162812 	 806
# 163620 	 808
# 164430 	 810
# 165242 	 812
# 166056 	 814
# 166872 	 816
# 167690 	 818
# 168510 	 820
# 169332 	 822
# 170156 	 824
# 170982 	 826
# 171810 	 828
# 172640 	 830
# 173472 	 832
# 174306 	 834
# 175142 	 836
# 175980 	 838
# 176820 	 840
# 177662 	 842
# 178506 	 844
# 179352 	 846
# 180200 	 848
# 181050 	 850
# 181902 	 852
# 182756 	 854
# 183612 	 856
# 184470 	 858
# 185330 	 860
# 186192 	 862
# 187056 	 864
# 187922 	 866
# 188790 	 868
# 189660 	 870
# 190532 	 872
# 191406 	 874
# 192282 	 876
# 193160 	 878
# 194040 	 880
# 194922 	 882
# 195806 	 884
# 196692 	 886
# 197580 	 888
# 198470 	 890
# 199362 	 892
# 200256 	 894
# 201152 	 896
# 202050 	 898
# 202950 	 900
# 203852 	 902
# 204756 	 904
# 205662 	 906
# 206570 	 908
# 207480 	 910
# 208392 	 912
# 209306 	 914
# 210222 	 916
# 211140 	 918
# 212060 	 920
# 212982 	 922
# 213906 	 924
# 214832 	 926
# 215760 	 928
# 216690 	 930
# 217622 	 932
# 218556 	 934
# 219492 	 936
# 220430 	 938
# 221370 	 940
# 222312 	 942
# 223256 	 944
# 224202 	 946
# 225150 	 948
# 226100 	 950
# 227052 	 952
# 228006 	 954
# 228962 	 956
# 229920 	 958
# 230880 	 960
# 231842 	 962
# 232806 	 964
# 233772 	 966
# 234740 	 968
# 235710 	 970
# 236682 	 972
# 237656 	 974
# 238632 	 976
# 239610 	 978
# 240590 	 980
# 241572 	 982
# 242556 	 984
# 243542 	 986
# 244530 	 988
# 245520 	 990
# 246512 	 992
# 247506 	 994
# 248502 	 996
# 249500 	 998
# final total: 249500

# %%
# don't keep copying and pasting old code

# %%
def total(lst):
    total_ = 0
    n = len(lst)
    for i in range(n):
        total_ += lst[i]
    return total_
total(values)
# Out:
# 249500

# %%
total([i for i in range(-1000,10000,53)])
# Out:
# 932984

# %%
import random
X1=[3,6,9,12,15,18,21,24,27,30]
X2=[random.randint(0,100) for i in range(10)]
total(X1), total(X2)
# Out:
# (165, 357)

# %% [markdown]
# ## Mean
# let x1,x2, ... xn represent random variables for a given dataset, useful descriptive statistics of central tendency inlude mean, median, and mode, which we bulit as functions in previous chapter.
#
# we define the mean of a set of numbers

# %%
def mean(lst):
    n =len(lst)
    mean_ = total(lst)/n
    return mean_
mean(X1),mean(X2)
# Out:
# (16.5, 35.7)

# %% [markdown]
# # now let's build the rest of the summary statistics functions
# 1. median
# 2. mode
# 3. variance
# 4. standard deviation
# 5. standard error
# 6. covariance
# 7. corelation

# %% [markdown]
# # #1 Median

# %%
def median(lst):
    n = len(lst)
    lst=sorted(lst)
    # two cases:
    #1. list of odd length
    # i % j checks for remainder upon dividing i by j
    if n%2!=0:
        middle_index = (n-1)/2
        median_=lst[middle_index]
    #2. list of even length
    else:
        upper_middle_index = int(n/2)
        lower_middle_index = upper_middle_index -1 
        #pass slice with two middle values to mean()
        median_=mean(lst[lower_middle_index: upper_middle_index +1])
    return median_    

median(X1), median(X2)
# Out:
# (16.5, 29.0)

# %% [markdown]
# # #2 Mode

# %%
def mode(lst):
    count_dct ={}
    #crate entries for each value with 0
    for key in lst:
        count_dct[key]=0
    #add up each occurence
    for key in lst:
        count_dct[key] +=1
    #calculate max count up front
    max_count=max(count_dct.values())
    #now we can compare each count to the max count
    mode_=[]
    for key, count in count_dct.items():
        if count == max_count:
            mode_.append(key)
    return mode_
lst = [1,2,3,4,5,5,5,5,5]
mode(lst)
# Out:
# [5]

# %%
lst2=[6,9,1,1,1,7,6]
mode(lst2)
# Out:
# [1]

# %% [markdown]
# # #3 Variance

# %%
def variance(lst,sample=True):
    list_mean=mean(lst)
    n=len(lst)
    DoF=n-1
    sum_sq_diff=0
    
    for val in lst:
        diff=val - list_mean
        sum_sq_diff += (diff)**2
        #print(val, list_mean, diff**2, sum_sq_diff)
    if sample == False:
        variance_= sum_sq_diff/n
    else:
        variance_=sum_sq_diff/ DoF
    return variance_
variance(X1), variance(X1,sample = False)
# Out:
# (82.5, 74.25)

# %%
variance(X2), variance(X2, sample = False)
# Out:
# (530.4555555555555, 477.40999999999997)

# %% [markdown]
# ## #4 Standard Deviation
# standard deviation is the square root of the variance

# %%
def SD(lst, sample =True):
    SD_ = variance(lst, sample)**(1/2)
    return SD_
SD(X1), SD(X1, sample = False)
# Out:
# (9.082951062292475, 8.616843969807043)

# %%
SD(X2), SD(X2, sample = False)
# Out:
# (23.03162077569782, 21.84971395693774)

# %% [markdown]
# ## #5 Standard Error

# %%
def STE(lst, sample= True):
    n = len(lst)
    se= SD(lst,sample)/n**(1/2)
    
    return se

# %%
SD(X1,sample = True),STE(X1,sample =True)
# Out:
# (9.082951062292475, 2.872281323269014)

# %% [markdown]
# ## #6 Covariance

# %%
def covariance(lst1, lst2, sample = False):
    # determine the mean of each list
    mean1 = mean(lst1)
    mean2 = mean(lst2)
    # instantiate a variable holding the value of 0; this will be used to 
    # sum the values generated in the for loop below
    cov = 0
    n1 = len(lst1)
    n2 = len(lst2)
    # check list lengths are equal
    if n1 == n2:
        n = n1
        # sum the product of the differences
        for i in range(n):
            cov += (lst1[i] - mean1) * (lst2[i] - mean2)
        if sample == False:
            cov = cov / n
        # account for sample by dividing by one less than number of elements in list
        else:
            cov = cov / (n - 1)
        # return covariance
        return cov
    else:
        print("List lengths are not equal")
        print("List1:", n1)
        print("List2:", n2)

# %%
covariance(X1,X2, sample = True)
# Out:
# 0.16666666666666666

# %%
covariance(X1[:-1],X2)
# Out:
# List lengths are not equal
# List1: 9
# List2: 10

# %% [markdown]
# ## #7 Correlation

# %%
def correlation(lst1,lst2):
    cov= covariance(lst1,lst2)
    SD1= SD(lst1)
    SD2= SD(lst2)
    corr = cov/(SD1*SD2)
    return corr
correlation(X1,X2)
# Out:
# 0.0007170340566878776

# %% [markdown]
# ## #8 Skewness

# %%
def skewness(lst, sample = True):
    mean_=mean(lst)
    SD_=SD(lst, sample)
    skew=0
    n=len(lst)
    for val in lst:
        skew += (val - mean_)**3
        skew= skew/ (n*SD_**3) if not sample else n * skew/((n-1)*(n-1)*SD_**3)
    return skew
skew1 = skewness(X1, sample = False)
skew2 = skewness(X2, sample = False)
print("skewness of list1:", skew1)
print("skewness of list2:", skew2)
sample_skew1 = skewness(X1, sample = True)
sample_skew2 = skewness(X2, sample = True)
print("sample skewness of list1:", sample_skew1)
print("sample skewness of list2:", sample_skew2)
# Out:
# skewness of list1: 0.3845816488010459
# skewness of list2: -0.004378329483199843
# sample skewness of list1: 0.40538626484163354
# sample skewness of list2: -0.004615264226517575

# %%
skewness(X1)
# Out:
# 0.40538626484163354

# %%
skewness(X2)
# Out:
# -0.004615264226517575

# %% [markdown]
# ## #9 Kurtosis

# %%
def kurtosis(lst, sample = False):
    mean_ = mean(lst)
    kurt = 0
    SD_ = SD(lst, sample)
    n = len(lst)
    for x in lst:
        kurt += (x - mean_) ** 4
    kurt = kurt / (n * SD_ ** 4) if  sample == False else  n * (n + 1) * kurt / \
    ((n - 1) * (n - 2) * (n - 3) * (SD_ ** 4)) - (3 *(n - 1) ** 2) / ((n - 2) * (n - 3))
    
    return kurt

# . . .
kurt1 = kurtosis(X1)
kurt2 = kurtosis(X2)
print("kurtosis of list1:", kurt1)
print("kurtosis of list2:", kurt2)
sample_kurt1 = kurtosis(X1, sample = True)  
sample_kurt2 = kurtosis(X2, sample = True)  
print("sample kurtosis of list1:", sample_kurt1)  
print("sample kurtosis of list2:", sample_kurt2)
# Out:
# kurtosis of list1: 1.7757575757575759
# kurtosis of list2: 5.009189111832375
# sample kurtosis of list1: -1.1999999999999997
# sample kurtosis of list2: 4.516245036989374

# %%
import pandas as pd
def gather_statistics(df, sample=False, round_dig=3):
    dct= {key:{}for key in df}
    for key, val in df.items():
        val.dropna(inplace=True)
        dct[key]["mean"]=round(mean(val), round_dig)
        dct[key]["median"]=round(median(val), round_dig)
        dct[key]["variance"]=round(variance(val), round_dig)
        dct[key]["S.D."] = round(SD(val, sample), round_dig)
        dct[key]["Skewness"]=round(skewness(val,sample), round_dig)
        dct[key]["Kurtosis"]=round(kurtosis(val,sample), round_dig)
    stats_df = pd.DataFrame(dct)
    return stats_df
    
data = pd.DataFrame([X1, X2], index = ["List1", "List2"]).T
gather_statistics(data, sample = False, round_dig=2)
# Out:
#           List1   List2
# mean      16.50   35.70
# median    16.50   29.00
# variance  82.50  530.46
# S.D.       8.62   21.85
# Skewness   0.38   -0.00
# Kurtosis   1.78    5.01

# %% [markdown]
# ## Frser Economic Freedom of the World

# %%
filename = "efotw-2022-master-index-data-for-researchers-iso.xlsx"
data = pd.read_excel(filename, 
                      index_col = [3,1],
                      header = [4])
data
# Out:
#                  Unnamed: 0 ISO Code 2      Countries  \
# ISO Code 3 Year
# ALB        2020         NaN         AL        Albania
# DZA        2020         NaN         DZ        Algeria
# AGO        2020         NaN         AO         Angola
# ARG        2020         NaN         AR      Argentina
# ARM        2020         NaN         AM        Armenia
# ...                     ...        ...            ...
# VEN        1970         NaN         VE  Venezuela, RB
# VNM        1970         NaN         VN        Vietnam
# YEM        1970         NaN         YE    Yemen, Rep.
# ZMB        1970         NaN         ZM         Zambia
# ZWE        1970         NaN         ZW       Zimbabwe
#
#                  Economic Freedom Summary Index   Rank  Quartile  \
# ISO Code 3 Year
# ALB        2020                            7.64   26.0       1.0
# DZA        2020                            5.12  157.0       4.0
# AGO        2020                            5.91  138.0       4.0
# ARG        2020                            4.87  161.0       4.0
# ARM        2020                            7.84   11.0       1.0
# ...                                         ...    ...       ...
# VEN        1970                            7.19   13.0       1.0
# VNM        1970                             NaN    NaN       NaN
# YEM        1970                             NaN    NaN       NaN
# ZMB        1970                            5.33   54.0       3.0
# ZWE        1970                             NaN    NaN       NaN
#
#                  1A Government Consumption       data  \
# ISO Code 3 Year
# ALB        2020                   8.026471  12.710000
# DZA        2020                   3.102941  29.450000
# AGO        2020                   7.700000  13.820000
# ARG        2020                   5.985294  19.650000
# ARM        2020                   6.605882  17.540000
# ...                                    ...        ...
# VEN        1970                   6.602003  17.553191
# VNM        1970                        NaN        NaN
# YEM        1970                        NaN        NaN
# ZMB        1970                   3.448131  28.276353
# ZWE        1970                   7.806922  13.456464
#
#                  1B  Transfers and subsidies     data.1  ...  Unnamed: 101  \
# ISO Code 3 Year                                          ...
# ALB        2020                     6.978202  11.590000  ...       2011.00
# DZA        2020                     7.817129   8.511137  ...        153.00
# AGO        2020                     9.702997   1.590000  ...         38.25
# ARG        2020                     6.493188  13.370000  ...        114.75
# ARM        2020                     7.223433  10.690000  ...         76.50
# ...                                      ...        ...  ...           ...
# VEN        1970                     9.827430   1.133333  ...           NaN
# VNM        1970                          NaN        NaN  ...           NaN
# YEM        1970                          NaN        NaN  ...           NaN
# ZMB        1970                     9.105430   3.783070  ...           NaN
# ZWE        1970                          NaN        NaN  ...           NaN
#
#                  Unnamed: 102  Unnamed: 103 Unnamed: 104  Unnamed: 105  \
# ISO Code 3 Year
# ALB        2020       2012.00       2013.00      2014.00       2015.00
# DZA        2020        153.00        157.00       159.00        159.00
# AGO        2020         38.25         39.25        39.75         39.75
# ARG        2020        114.75        117.75       119.25        119.25
# ARM        2020         76.50         78.50        79.50         79.50
# ...                       ...           ...          ...           ...
# VEN        1970           NaN           NaN          NaN           NaN
# VNM        1970           NaN           NaN          NaN           NaN
# YEM        1970           NaN           NaN          NaN           NaN
# ZMB        1970           NaN           NaN          NaN           NaN
# ZWE        1970           NaN           NaN          NaN           NaN
#
#                 Unnamed: 106  Unnamed: 107  Unnamed: 108  Unnamed: 109  \
# ISO Code 3 Year
# ALB        2020       2016.0        2017.0        2018.0       2019.00
# DZA        2020        162.0         162.0         162.0        165.00
# AGO        2020         40.5          40.5          40.5         41.25
# ARG        2020        121.5         121.5         121.5        123.75
# ARM        2020         81.0          81.0          81.0         82.50
# ...                      ...           ...           ...           ...
# VEN        1970          NaN           NaN           NaN           NaN
# VNM        1970          NaN           NaN           NaN           NaN
# YEM        1970          NaN           NaN           NaN           NaN
# ZMB        1970          NaN           NaN           NaN           NaN
# ZWE        1970          NaN           NaN           NaN           NaN
#
#                  Unnamed: 110
# ISO Code 3 Year
# ALB        2020       2020.00
# DZA        2020        165.00
# AGO        2020         41.25
# ARG        2020        123.75
# ARM        2020         82.50
# ...                       ...
# VEN        1970           NaN
# VNM        1970           NaN
# YEM        1970           NaN
# ZMB        1970           NaN
# ZWE        1970           NaN
#
# [4455 rows x 109 columns]

# %%
data = pd.read_excel(filename, 
                     index_col = [2,0], 
                     header = [0],
                     sheet_name = "EFW Panel Data 2022 Report")
rename = {"Panel Data Summary Index": "Summary",
         "Area 1":"Size of Government",
         "Area 2":"Legal System and Property Rights",
         "Area 3":"Sound Money",
         "Area 4":"Freedom to Trade Internationally",
         "Area 5":"Regulation"}
data = data.dropna(how="all", axis = 1).rename(columns = rename)
data = data[data.keys()[4:-1]]
data
# Out:
#                   Summary  Size of Government  \
# ISO_Code_3 Year
# ALB        2020  7.640000            7.817077
# DZA        2020  5.120000            4.409943
# AGO        2020  5.910000            8.133385
# ARG        2020  4.870000            6.483768
# ARM        2020  7.840000            7.975292
# ...                   ...                 ...
# VEN        1970  7.242943            8.349529
# VNM        1970       NaN                 NaN
# YEM        1970       NaN                 NaN
# ZMB        1970  4.498763            5.374545
# ZWE        1970       NaN                 NaN
#
#                  Legal System and Property Rights  Sound Money  \
# ISO_Code_3 Year
# ALB        2020                          5.260351     9.788269
# DZA        2020                          4.131760     7.630287
# AGO        2020                          3.705161     6.087996
# ARG        2020                          4.796454     4.516018
# ARM        2020                          6.236215     9.553009
# ...                                           ...          ...
# VEN        1970                          5.003088     9.621851
# VNM        1970                               NaN          NaN
# YEM        1970                               NaN          NaN
# ZMB        1970                          4.472812     5.137395
# ZWE        1970                               NaN          NaN
#
#                  Freedom to Trade Internationally  Regulation
# ISO_Code_3 Year
# ALB        2020                          8.222499    7.112958
# DZA        2020                          3.639507    5.778953
# AGO        2020                          5.373190    6.227545
# ARG        2020                          3.086907    5.490538
# ARM        2020                          7.692708    7.756333
# ...                                           ...         ...
# VEN        1970                          7.895993    5.209592
# VNM        1970                               NaN         NaN
# YEM        1970                               NaN         NaN
# ZMB        1970                               NaN    5.307952
# ZWE        1970                               NaN         NaN
#
# [4455 rows x 6 columns]

# %%
file = pd.ExcelFile(filename)
file.sheet_names

for sheet_name in file.sheet_names:
    print(sheet_name)
    print(pd.read_excel(filename,header=[4],
                       index_col = [3,1],
                       sheet_name = sheet_name))
# Out:
# EFW Data 2022 Report
#                  Unnamed: 0 ISO Code 2      Countries  \
# ISO Code 3 Year
# ALB        2020         NaN         AL        Albania
# DZA        2020         NaN         DZ        Algeria
# AGO        2020         NaN         AO         Angola
# ARG        2020         NaN         AR      Argentina
# ARM        2020         NaN         AM        Armenia
# ...                     ...        ...            ...
# VEN        1970         NaN         VE  Venezuela, RB
# VNM        1970         NaN         VN        Vietnam
# YEM        1970         NaN         YE    Yemen, Rep.
# ZMB        1970         NaN         ZM         Zambia
# ZWE        1970         NaN         ZW       Zimbabwe
#
#                  Economic Freedom Summary Index   Rank  Quartile  \
# ISO Code 3 Year
# ALB        2020                            7.64   26.0       1.0
# DZA        2020                            5.12  157.0       4.0
# AGO        2020                            5.91  138.0       4.0
# ARG        2020                            4.87  161.0       4.0
# ARM        2020                            7.84   11.0       1.0
# ...                                         ...    ...       ...
# VEN        1970                            7.19   13.0       1.0
# VNM        1970                             NaN    NaN       NaN
# YEM        1970                             NaN    NaN       NaN
# ZMB        1970                            5.33   54.0       3.0
# ZWE        1970                             NaN    NaN       NaN
#
#                  1A Government Consumption       data  \
# ISO Code 3 Year
# ALB        2020                   8.026471  12.710000
# DZA        2020                   3.102941  29.450000
# AGO        2020                   7.700000  13.820000
# ARG        2020                   5.985294  19.650000
# ARM        2020                   6.605882  17.540000
# ...                                    ...        ...
# VEN        1970                   6.602003  17.553191
# VNM        1970                        NaN        NaN
# YEM        1970                        NaN        NaN
# ZMB        1970                   3.448131  28.276353
# ZWE        1970                   7.806922  13.456464
#
#                  1B  Transfers and subsidies     data.1  ...  Unnamed: 101  \
# ISO Code 3 Year                                          ...
# ALB        2020                     6.978202  11.590000  ...       2011.00
# DZA        2020                     7.817129   8.511137  ...        153.00
# AGO        2020                     9.702997   1.590000  ...         38.25
# ARG        2020                     6.493188  13.370000  ...        114.75
# ARM        2020                     7.223433  10.690000  ...         76.50
# ...                                      ...        ...  ...           ...
# VEN        1970                     9.827430   1.133333  ...           NaN
# VNM        1970                          NaN        NaN  ...           NaN
# YEM        1970                          NaN        NaN  ...           NaN
# ZMB        1970                     9.105430   3.783070  ...           NaN
# ZWE        1970                          NaN        NaN  ...           NaN
#
#                  Unnamed: 102  Unnamed: 103 Unnamed: 104  Unnamed: 105  \
# ISO Code 3 Year
# ALB        2020       2012.00       2013.00      2014.00       2015.00
# DZA        2020        153.00        157.00       159.00        159.00
# AGO        2020         38.25         39.25        39.75         39.75
# ARG        2020        114.75        117.75       119.25        119.25
# ARM        2020         76.50         78.50        79.50         79.50
# ...                       ...           ...          ...           ...
# VEN        1970           NaN           NaN          NaN           NaN
# VNM        1970           NaN           NaN          NaN           NaN
# YEM        1970           NaN           NaN          NaN           NaN
# ZMB        1970           NaN           NaN          NaN           NaN
# ZWE        1970           NaN           NaN          NaN           NaN
#
#                 Unnamed: 106  Unnamed: 107  Unnamed: 108  Unnamed: 109  \
# ISO Code 3 Year
# ALB        2020       2016.0        2017.0        2018.0       2019.00
# DZA        2020        162.0         162.0         162.0        165.00
# AGO        2020         40.5          40.5          40.5         41.25
# ARG        2020        121.5         121.5         121.5        123.75
# ARM        2020         81.0          81.0          81.0         82.50
# ...                      ...           ...           ...           ...
# VEN        1970          NaN           NaN           NaN           NaN
# VNM        1970          NaN           NaN           NaN           NaN
# YEM        1970          NaN           NaN           NaN           NaN
# ZMB        1970          NaN           NaN           NaN           NaN
# ZWE        1970          NaN           NaN           NaN           NaN
#
#                  Unnamed: 110
# ISO Code 3 Year
# ALB        2020       2020.00
# DZA        2020        165.00
# AGO        2020         41.25
# ARG        2020        123.75
# ARM        2020         82.50
# ...                       ...
# VEN        1970           NaN
# VNM        1970           NaN
# YEM        1970           NaN
# ZMB        1970           NaN
# ZWE        1970           NaN
#
# [4455 rows x 109 columns]
# EFW Panel Data 2022 Report
#                                   2020  ARG   UM      Argentina      4.87  \
# Latin America & the Caribbean AR
# Europe & Central Asia         AM  2020  ARM   UM        Armenia  7.840000
# East Asia & Pacific           AU  2020  AUS    H      Australia  8.040000
# Europe & Central Asia         AT  2020  AUT    H        Austria  7.560000
#                               AZ  2020  AZE   UM     Azerbaijan  6.210000
# Latin America & the Caribbean BS  2020  BHS    H   Bahamas, The  7.020000
# ...                                ...  ...  ...            ...       ...
#                               VE  1970  VEN  NaN  Venezuela, RB  7.242943
# East Asia & Pacific           VN  1970  VNM  NaN        Vietnam       NaN
# Middle East & North Africa    YE  1970  YEM  NaN    Yemen, Rep.       NaN
# Sub-Saharan Africa            ZM  1970  ZMB  NaN         Zambia  4.498763
#                               ZW  1970  ZWE  NaN       Zimbabwe       NaN
#
#                                   6.483767854280677  4.796453856217683  \
# Latin America & the Caribbean AR
# Europe & Central Asia         AM           7.975292           6.236215
# East Asia & Pacific           AU           6.091321           8.336755
# Europe & Central Asia         AT           4.929120           8.388811
#                               AZ           4.550381           5.243687
# Latin America & the Caribbean BS           8.646436           6.225554
# ...                                             ...                ...
#                               VE           8.349529           5.003088
# East Asia & Pacific           VN                NaN                NaN
# Middle East & North Africa    YE                NaN                NaN
# Sub-Saharan Africa            ZM           5.374545           4.472812
#                               ZW                NaN                NaN
#
#                                   4.516017683088538  3.086906776460489  \
# Latin America & the Caribbean AR
# Europe & Central Asia         AM           9.553009           7.692708
# East Asia & Pacific           AU           9.557660           7.918387
# Europe & Central Asia         AT           9.181004           8.094356
#                               AZ           7.268722           7.012122
# Latin America & the Caribbean BS           6.804486           5.215014
# ...                                             ...                ...
#                               VE           9.621851           7.895993
# East Asia & Pacific           VN                NaN                NaN
# Middle East & North Africa    YE                NaN                NaN
# Sub-Saharan Africa            ZM           5.137395                NaN
#                               ZW                NaN                NaN
#
#                                   5.490538424517783  1.254923941080943
# Latin America & the Caribbean AR
# Europe & Central Asia         AM           7.756333           1.178292
# East Asia & Pacific           AU           8.272967           1.250766
# Europe & Central Asia         AT           7.201705           1.631718
#                               AZ           6.959071           1.226116
# Latin America & the Caribbean BS           8.232494           1.418704
# ...                                             ...                ...
#                               VE           5.209592           2.028426
# East Asia & Pacific           VN                NaN                NaN
# Middle East & North Africa    YE                NaN                NaN
# Sub-Saharan Africa            ZM           5.307952           0.412514
#                               ZW                NaN                NaN
#
# [4451 rows x 11 columns]
# EFW Data 1950_1965
#                  1965.000000  5.675413
# 52  Argentina
# 9   Australia           1965     7.387365
# 20  Austria             1965     6.626116
# 11  Belgium             1965     7.279489
# 107 Benin               1965     3.884034
# 30  Bolivia             1965     6.247613
# ...                      ...          ...
# 34  Uruguay             1950     5.927550
# 20  Venezuela           1950     6.304037
# 42  Yemen, Rep.         1950     5.628150
# 73  Zambia              1950     4.069384
# 79  Zimbabwe            1950     3.830576
#
# [454 rows x 2 columns]

# %%
sheet_name=file.sheet_names[1]
data=pd.read_excel(filename,
                  sheet_name = sheet_name)
rename = {"Panel Data Summary Index": "Summary",
         "Area 1":"Size of Government",
         "Area 2":"Legal System and Property Rights",
         "Area 3":"Sound Money",
         "Area 4":"Freedom to Trade Internationally",
         "Area 5":"Regulation"}
data.rename(columns = rename)
# Out:
#       Year ISO_Code_2 ISO_Code_3              World Bank Region  \
# 0     2020         AL        ALB          Europe & Central Asia
# 1     2020         DZ        DZA     Middle East & North Africa
# 2     2020         AO        AGO             Sub-Saharan Africa
# 3     2020         AR        ARG  Latin America & the Caribbean
# 4     2020         AM        ARM          Europe & Central Asia
# ...    ...        ...        ...                            ...
# 4450  1970         VE        VEN  Latin America & the Caribbean
# 4451  1970         VN        VNM            East Asia & Pacific
# 4452  1970         YE        YEM     Middle East & North Africa
# 4453  1970         ZM        ZMB             Sub-Saharan Africa
# 4454  1970         ZW        ZWE             Sub-Saharan Africa
#
#      World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 0                                                    UM
# 1                                                    LM
# 2                                                    LM
# 3                                                    UM
# 4                                                    UM
# ...                                                 ...
# 4450                                                NaN
# 4451                                                NaN
# 4452                                                NaN
# 4453                                                NaN
# 4454                                                NaN
#
#           Countries   Summary  Size of Government  \
# 0           Albania  7.640000            7.817077
# 1           Algeria  5.120000            4.409943
# 2            Angola  5.910000            8.133385
# 3         Argentina  4.870000            6.483768
# 4           Armenia  7.840000            7.975292
# ...             ...       ...                 ...
# 4450  Venezuela, RB  7.242943            8.349529
# 4451        Vietnam       NaN                 NaN
# 4452    Yemen, Rep.       NaN                 NaN
# 4453         Zambia  4.498763            5.374545
# 4454       Zimbabwe       NaN                 NaN
#
#       Legal System and Property Rights  Sound Money  \
# 0                             5.260351     9.788269
# 1                             4.131760     7.630287
# 2                             3.705161     6.087996
# 3                             4.796454     4.516018
# 4                             6.236215     9.553009
# ...                                ...          ...
# 4450                          5.003088     9.621851
# 4451                               NaN          NaN
# 4452                               NaN          NaN
# 4453                          4.472812     5.137395
# 4454                               NaN          NaN
#
#       Freedom to Trade Internationally  Regulation  \
# 0                             8.222499    7.112958
# 1                             3.639507    5.778953
# 2                             5.373190    6.227545
# 3                             3.086907    5.490538
# 4                             7.692708    7.756333
# ...                                ...         ...
# 4450                          7.895993    5.209592
# 4451                               NaN         NaN
# 4452                               NaN         NaN
# 4453                               NaN    5.307952
# 4454                               NaN         NaN
#
#       Standard Deviation of the 5 EFW Areas
# 0                                  1.652742
# 1                                  1.613103
# 2                                  1.598854
# 3                                  1.254924
# 4                                  1.178292
# ...                                     ...
# 4450                               2.028426
# 4451                                    NaN
# 4452                                    NaN
# 4453                               0.412514
# 4454                                    NaN
#
# [4455 rows x 13 columns]

# %%
data.keys()
# Out:
# Index(['Year', 'ISO_Code_2', 'ISO_Code_3', 'World Bank Region',
#        'World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)',
#        'Countries', 'Panel Data Summary Index', 'Area 1', 'Area 2', 'Area 3',
#        'Area 4', 'Area 5', 'Standard Deviation of the 5 EFW Areas'],
#       dtype='object')

# %%
data.keys()[4]
# Out:
# 'World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)'

# %%
income_levels = data.keys()[4]
#access the unique values by using .unique()
data[income_levels].unique()
# Out:
# array(['UM', 'LM', 'H', 'L', nan, '..'], dtype=object)

# %%
high_income_bool=data[income_levels]=="H"
data[high_income_bool]
# Out:
#       Year ISO_Code_2 ISO_Code_3              World Bank Region  \
# 5     2020         AU        AUS            East Asia & Pacific
# 6     2020         AT        AUT          Europe & Central Asia
# 8     2020         BS        BHS  Latin America & the Caribbean
# 9     2020         BH        BHR     Middle East & North Africa
# 11    2020         BB        BRB  Latin America & the Caribbean
# ...    ...        ...        ...                            ...
# 3772  1990         SE        SWE          Europe & Central Asia
# 3773  1990         CH        CHE          Europe & Central Asia
# 3786  1990         AE        ARE     Middle East & North Africa
# 3787  1990         GB        GBR          Europe & Central Asia
# 3788  1990         US        USA                  North America
#
#      World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 5                                                     H
# 6                                                     H
# 8                                                     H
# 9                                                     H
# 11                                                    H
# ...                                                 ...
# 3772                                                  H
# 3773                                                  H
# 3786                                                  H
# 3787                                                  H
# 3788                                                  H
#
#                  Countries  Panel Data Summary Index    Area 1    Area 2  \
# 5                Australia                  8.040000  6.091321  8.336755
# 6                  Austria                  7.560000  4.929120  8.388811
# 8             Bahamas, The                  7.020000  8.646436  6.225554
# 9                  Bahrain                  7.470000  7.081093  4.918487
# 11                Barbados                  7.010000  7.324463  5.912525
# ...                    ...                       ...       ...       ...
# 3772                Sweden                  7.273645  4.105904  8.206651
# 3773           Switzerland                  8.537019  7.449348  8.851723
# 3786  United Arab Emirates                  6.756066  5.767890  4.101529
# 3787        United Kingdom                  8.200173  6.519684  8.164475
# 3788         United States                  8.461126  7.262163  8.350956
#
#         Area 3    Area 4    Area 5  Standard Deviation of the 5 EFW Areas
# 5     9.557660  7.918387  8.272967                               1.250766
# 6     9.181004  8.094356  7.201705                               1.631718
# 8     6.804486  5.215014  8.232494                               1.418704
# 9     9.429684  8.261121  7.682671                               1.671289
# 11    8.184047  6.018961  7.624463                               1.005162
# ...        ...       ...       ...                                    ...
# 3772  8.030525  9.213997  6.810469                               1.965798
# 3773  9.598746  9.294085  7.431171                               1.025263
# 3786  7.962369       NaN  7.527121                               1.768182
# 3787  8.482826  9.139436  8.650617                               0.998742
# 3788  9.669842  8.537828  8.477998                               0.853932
#
# [1013 rows x 13 columns]

# %%
um_income_bool= data[income_levels]=="UM"
data[um_income_bool]
# Out:
#       Year ISO_Code_2 ISO_Code_3              World Bank Region  \
# 0     2020         AL        ALB          Europe & Central Asia
# 3     2020         AR        ARG  Latin America & the Caribbean
# 4     2020         AM        ARM          Europe & Central Asia
# 7     2020         AZ        AZE          Europe & Central Asia
# 12    2020         BY        BLR          Europe & Central Asia
# ...    ...        ...        ...                            ...
# 3767  1990         ZA        ZAF             Sub-Saharan Africa
# 3771  1990         SR        SUR  Latin America & the Caribbean
# 3781  1990         TT        TTO  Latin America & the Caribbean
# 3789  1990         UY        URY  Latin America & the Caribbean
# 3790  1990         VE        VEN  Latin America & the Caribbean
#
#      World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 0                                                    UM
# 3                                                    UM
# 4                                                    UM
# 7                                                    UM
# 12                                                   UM
# ...                                                 ...
# 3767                                                 UM
# 3771                                                 UM
# 3781                                                 UM
# 3789                                                 UM
# 3790                                                 UM
#
#                 Countries  Panel Data Summary Index    Area 1    Area 2  \
# 0                 Albania                  7.640000  7.817077  5.260351
# 3               Argentina                  4.870000  6.483768  4.796454
# 4                 Armenia                  7.840000  7.975292  6.236215
# 7              Azerbaijan                  6.210000  4.550381  5.243687
# 12                Belarus                  6.830000  5.236437  5.473420
# ...                   ...                       ...       ...       ...
# 3767         South Africa                  5.807061  6.891035  3.942684
# 3771             Suriname                       NaN       NaN       NaN
# 3781  Trinidad and Tobago                  5.621522  6.772555  4.975782
# 3789              Uruguay                  6.262442  7.026737  5.856224
# 3790        Venezuela, RB                  5.583700  7.128136  4.902547
#
#         Area 3    Area 4    Area 5  Standard Deviation of the 5 EFW Areas
# 0     9.788269  8.222499  7.112958                               1.652742
# 3     4.516018  3.086907  5.490538                               1.254924
# 4     9.553009  7.692708  7.756333                               1.178292
# 7     7.268722  7.012122  6.959071                               1.226116
# 12    9.163656  7.302753  6.980477                               1.586807
# ...        ...       ...       ...                                    ...
# 3767  5.876524  6.750809  5.855771                               1.176107
# 3771       NaN       NaN       NaN                                    NaN
# 3781  5.996212  2.798939  7.777625                               1.903213
# 3789  3.762722  7.503044  7.137626                               1.525014
# 3790  4.060094  6.754464  5.024922                               1.308920
#
# [826 rows x 13 columns]

# %%
data[high_income_bool | um_income_bool]
# Out:
#       Year ISO_Code_2 ISO_Code_3              World Bank Region  \
# 0     2020         AL        ALB          Europe & Central Asia
# 3     2020         AR        ARG  Latin America & the Caribbean
# 4     2020         AM        ARM          Europe & Central Asia
# 5     2020         AU        AUS            East Asia & Pacific
# 6     2020         AT        AUT          Europe & Central Asia
# ...    ...        ...        ...                            ...
# 3786  1990         AE        ARE     Middle East & North Africa
# 3787  1990         GB        GBR          Europe & Central Asia
# 3788  1990         US        USA                  North America
# 3789  1990         UY        URY  Latin America & the Caribbean
# 3790  1990         VE        VEN  Latin America & the Caribbean
#
#      World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 0                                                    UM
# 3                                                    UM
# 4                                                    UM
# 5                                                     H
# 6                                                     H
# ...                                                 ...
# 3786                                                  H
# 3787                                                  H
# 3788                                                  H
# 3789                                                 UM
# 3790                                                 UM
#
#                  Countries  Panel Data Summary Index    Area 1    Area 2  \
# 0                  Albania                  7.640000  7.817077  5.260351
# 3                Argentina                  4.870000  6.483768  4.796454
# 4                  Armenia                  7.840000  7.975292  6.236215
# 5                Australia                  8.040000  6.091321  8.336755
# 6                  Austria                  7.560000  4.929120  8.388811
# ...                    ...                       ...       ...       ...
# 3786  United Arab Emirates                  6.756066  5.767890  4.101529
# 3787        United Kingdom                  8.200173  6.519684  8.164475
# 3788         United States                  8.461126  7.262163  8.350956
# 3789               Uruguay                  6.262442  7.026737  5.856224
# 3790         Venezuela, RB                  5.583700  7.128136  4.902547
#
#         Area 3    Area 4    Area 5  Standard Deviation of the 5 EFW Areas
# 0     9.788269  8.222499  7.112958                               1.652742
# 3     4.516018  3.086907  5.490538                               1.254924
# 4     9.553009  7.692708  7.756333                               1.178292
# 5     9.557660  7.918387  8.272967                               1.250766
# 6     9.181004  8.094356  7.201705                               1.631718
# ...        ...       ...       ...                                    ...
# 3786  7.962369       NaN  7.527121                               1.768182
# 3787  8.482826  9.139436  8.650617                               0.998742
# 3788  9.669842  8.537828  8.477998                               0.853932
# 3789  3.762722  7.503044  7.137626                               1.525014
# 3790  4.060094  6.754464  5.024922                               1.308920
#
# [1839 rows x 13 columns]

# %%
data.dropna()
# Out:
#       Year ISO_Code_2 ISO_Code_3              World Bank Region  \
# 0     2020         AL        ALB          Europe & Central Asia
# 1     2020         DZ        DZA     Middle East & North Africa
# 2     2020         AO        AGO             Sub-Saharan Africa
# 3     2020         AR        ARG  Latin America & the Caribbean
# 4     2020         AM        ARM          Europe & Central Asia
# ...    ...        ...        ...                            ...
# 3788  1990         US        USA                  North America
# 3789  1990         UY        URY  Latin America & the Caribbean
# 3790  1990         VE        VEN  Latin America & the Caribbean
# 3793  1990         ZM        ZMB             Sub-Saharan Africa
# 3794  1990         ZW        ZWE             Sub-Saharan Africa
#
#      World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 0                                                    UM
# 1                                                    LM
# 2                                                    LM
# 3                                                    UM
# 4                                                    UM
# ...                                                 ...
# 3788                                                  H
# 3789                                                 UM
# 3790                                                 UM
# 3793                                                  L
# 3794                                                 LM
#
#           Countries  Panel Data Summary Index    Area 1    Area 2    Area 3  \
# 0           Albania                  7.640000  7.817077  5.260351  9.788269
# 1           Algeria                  5.120000  4.409943  4.131760  7.630287
# 2            Angola                  5.910000  8.133385  3.705161  6.087996
# 3         Argentina                  4.870000  6.483768  4.796454  4.516018
# 4           Armenia                  7.840000  7.975292  6.236215  9.553009
# ...             ...                       ...       ...       ...       ...
# 3788  United States                  8.461126  7.262163  8.350956  9.669842
# 3789        Uruguay                  6.262442  7.026737  5.856224  3.762722
# 3790  Venezuela, RB                  5.583700  7.128136  4.902547  4.060094
# 3793         Zambia                  3.326383  4.917139  4.473783  0.463128
# 3794       Zimbabwe                  5.037441  5.636731  4.573183  6.053152
#
#         Area 4    Area 5  Standard Deviation of the 5 EFW Areas
# 0     8.222499  7.112958                               1.652742
# 1     3.639507  5.778953                               1.613103
# 2     5.373190  6.227545                               1.598854
# 3     3.086907  5.490538                               1.254924
# 4     7.692708  7.756333                               1.178292
# ...        ...       ...                                    ...
# 3788  8.537828  8.477998                               0.853932
# 3789  7.503044  7.137626                               1.525014
# 3790  6.754464  5.024922                               1.308920
# 3793  2.201444  4.697057                               1.948499
# 3794  5.101322  4.084720                               0.791264
#
# [3270 rows x 13 columns]

# %%
data.dropna(axis = 1, how = "any")
# Out:
#       Year ISO_Code_3              World Bank Region      Countries
# 0     2020        ALB          Europe & Central Asia        Albania
# 1     2020        DZA     Middle East & North Africa        Algeria
# 2     2020        AGO             Sub-Saharan Africa         Angola
# 3     2020        ARG  Latin America & the Caribbean      Argentina
# 4     2020        ARM          Europe & Central Asia        Armenia
# ...    ...        ...                            ...            ...
# 4450  1970        VEN  Latin America & the Caribbean  Venezuela, RB
# 4451  1970        VNM            East Asia & Pacific        Vietnam
# 4452  1970        YEM     Middle East & North Africa    Yemen, Rep.
# 4453  1970        ZMB             Sub-Saharan Africa         Zambia
# 4454  1970        ZWE             Sub-Saharan Africa       Zimbabwe
#
# [4455 rows x 4 columns]

# %%
data_for_stats = data.dropna(how="any")
data
# Out:
#       Year ISO_Code_2 ISO_Code_3              World Bank Region  \
# 0     2020         AL        ALB          Europe & Central Asia
# 1     2020         DZ        DZA     Middle East & North Africa
# 2     2020         AO        AGO             Sub-Saharan Africa
# 3     2020         AR        ARG  Latin America & the Caribbean
# 4     2020         AM        ARM          Europe & Central Asia
# ...    ...        ...        ...                            ...
# 4450  1970         VE        VEN  Latin America & the Caribbean
# 4451  1970         VN        VNM            East Asia & Pacific
# 4452  1970         YE        YEM     Middle East & North Africa
# 4453  1970         ZM        ZMB             Sub-Saharan Africa
# 4454  1970         ZW        ZWE             Sub-Saharan Africa
#
#      World Bank Current Income Classification, 1990-present (L=Low income, LM=Lower middle income, UM=Upper middle income, H=High income)  \
# 0                                                    UM
# 1                                                    LM
# 2                                                    LM
# 3                                                    UM
# 4                                                    UM
# ...                                                 ...
# 4450                                                NaN
# 4451                                                NaN
# 4452                                                NaN
# 4453                                                NaN
# 4454                                                NaN
#
#           Countries  Panel Data Summary Index    Area 1    Area 2    Area 3  \
# 0           Albania                  7.640000  7.817077  5.260351  9.788269
# 1           Algeria                  5.120000  4.409943  4.131760  7.630287
# 2            Angola                  5.910000  8.133385  3.705161  6.087996
# 3         Argentina                  4.870000  6.483768  4.796454  4.516018
# 4           Armenia                  7.840000  7.975292  6.236215  9.553009
# ...             ...                       ...       ...       ...       ...
# 4450  Venezuela, RB                  7.242943  8.349529  5.003088  9.621851
# 4451        Vietnam                       NaN       NaN       NaN       NaN
# 4452    Yemen, Rep.                       NaN       NaN       NaN       NaN
# 4453         Zambia                  4.498763  5.374545  4.472812  5.137395
# 4454       Zimbabwe                       NaN       NaN       NaN       NaN
#
#         Area 4    Area 5  Standard Deviation of the 5 EFW Areas
# 0     8.222499  7.112958                               1.652742
# 1     3.639507  5.778953                               1.613103
# 2     5.373190  6.227545                               1.598854
# 3     3.086907  5.490538                               1.254924
# 4     7.692708  7.756333                               1.178292
# ...        ...       ...                                    ...
# 4450  7.895993  5.209592                               2.028426
# 4451       NaN       NaN                                    NaN
# 4452       NaN       NaN                                    NaN
# 4453       NaN  5.307952                               0.412514
# 4454       NaN       NaN                                    NaN
#
# [4455 rows x 13 columns]

# %%
stats_DF = gather_statistics(data_for_stats, sample = False)
stats_DF
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# D:\python\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# D:\python\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 106
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19044\1880137590.py in <module>
# ----> 1 stats_DF = gather_statistics(data_for_stats, sample = False)
#       2 stats_DF
#
# ~\AppData\Local\Temp\ipykernel_19044\106430396.py in gather_statistics(df, sample, round_dig)
#       4     for key, val in df.items():
#       5         val.dropna(inplace=True)
# ----> 6         dct[key]["mean"]=round(mean(val), round_dig)
#       7         dct[key]["median"]=round(median(val), round_dig)
#       8         dct[key]["variance"]=round(variance(val), round_dig)
#
# ~\AppData\Local\Temp\ipykernel_19044\2536009406.py in mean(lst)
#       1 def mean(lst):
#       2     n =len(lst)
# ----> 3     mean_ = total(lst)/n
#       4     return mean_
#       5 mean(X1),mean(X2)
#
# ~\AppData\Local\Temp\ipykernel_19044\2516588976.py in total(lst)
#       3     n = len(lst)
#       4     for i in range(n):
# ----> 5         total_ += lst[i]
#       6     return total_
#       7 total(values)
#
# D:\python\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     956
#     957         elif key_is_scalar:
# --> 958             return self._get_value(key)
#     959
#     960         if is_hashable(key):
#
# D:\python\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1067
#    1068         # Similar to Index.get_value, but we do not fall back to positional
# -> 1069         loc = self.index.get_loc(label)
#    1070         return self.index._get_values_for_loc(self, loc, label)
#    1071
#
# D:\python\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 106

# %%
cov_DF = data_for_stats.cov().round(2)
cov_DF
# Out:
#                                         Year  Panel Data Summary Index  \
# Year                                   53.59                      1.22
# Panel Data Summary Index                1.22                      1.10
# Area 1                                  0.42                      0.30
# Area 2                                  0.26                      1.38
# Area 3                                  2.85                      1.45
# Area 4                                  0.83                      1.37
# Area 5                                  1.67                      1.00
# Standard Deviation of the 5 EFW Areas  -0.01                     -0.06
#
#                                        Area 1  Area 2  Area 3  Area 4  Area 5  \
# Year                                     0.42    0.26    2.85    0.83    1.67
# Panel Data Summary Index                 0.30    1.38    1.45    1.37    1.00
# Area 1                                   1.35   -0.27    0.14    0.13    0.14
# Area 2                                  -0.27    2.71    1.53    1.65    1.26
# Area 3                                   0.14    1.53    2.70    1.71    1.15
# Area 4                                   0.13    1.65    1.71    2.22    1.11
# Area 5                                   0.14    1.26    1.15    1.11    1.31
# Standard Deviation of the 5 EFW Areas    0.03   -0.26    0.08   -0.04   -0.09
#
#                                        Standard Deviation of the 5 EFW Areas
# Year                                                                   -0.01
# Panel Data Summary Index                                               -0.06
# Area 1                                                                  0.03
# Area 2                                                                 -0.26
# Area 3                                                                  0.08
# Area 4                                                                 -0.04
# Area 5                                                                 -0.09
# Standard Deviation of the 5 EFW Areas                                   0.17

# %%
corr_DF=data_for_stats.corr().round(2)
corr_DF
# Out:
#                                        Year  Panel Data Summary Index  Area 1  \
# Year                                   1.00                      0.16    0.05
# Panel Data Summary Index               0.16                      1.00    0.25
# Area 1                                 0.05                      0.25    1.00
# Area 2                                 0.02                      0.80   -0.14
# Area 3                                 0.24                      0.84    0.08
# Area 4                                 0.08                      0.88    0.08
# Area 5                                 0.20                      0.83    0.11
# Standard Deviation of the 5 EFW Areas -0.00                     -0.13    0.06
#
#                                        Area 2  Area 3  Area 4  Area 5  \
# Year                                     0.02    0.24    0.08    0.20
# Panel Data Summary Index                 0.80    0.84    0.88    0.83
# Area 1                                  -0.14    0.08    0.08    0.11
# Area 2                                   1.00    0.57    0.68    0.67
# Area 3                                   0.57    1.00    0.70    0.61
# Area 4                                   0.68    0.70    1.00    0.65
# Area 5                                   0.67    0.61    0.65    1.00
# Standard Deviation of the 5 EFW Areas   -0.37    0.11   -0.06   -0.19
#
#                                        Standard Deviation of the 5 EFW Areas
# Year                                                                   -0.00
# Panel Data Summary Index                                               -0.13
# Area 1                                                                  0.06
# Area 2                                                                 -0.37
# Area 3                                                                  0.11
# Area 4                                                                 -0.06
# Area 5                                                                 -0.19
# Standard Deviation of the 5 EFW Areas                                   1.00

# %%
data_for_stats.corr().round(2).sort_index(axis =1).sort_index(axis=0)
# Out:
#                                        Area 1  Area 2  Area 3  Area 4  Area 5  \
# Area 1                                   1.00   -0.14    0.08    0.08    0.11
# Area 2                                  -0.14    1.00    0.57    0.68    0.67
# Area 3                                   0.08    0.57    1.00    0.70    0.61
# Area 4                                   0.08    0.68    0.70    1.00    0.65
# Area 5                                   0.11    0.67    0.61    0.65    1.00
# Panel Data Summary Index                 0.25    0.80    0.84    0.88    0.83
# Standard Deviation of the 5 EFW Areas    0.06   -0.37    0.11   -0.06   -0.19
# Year                                     0.05    0.02    0.24    0.08    0.20
#
#                                        Panel Data Summary Index  \
# Area 1                                                     0.25
# Area 2                                                     0.80
# Area 3                                                     0.84
# Area 4                                                     0.88
# Area 5                                                     0.83
# Panel Data Summary Index                                   1.00
# Standard Deviation of the 5 EFW Areas                     -0.13
# Year                                                       0.16
#
#                                        Standard Deviation of the 5 EFW Areas  \
# Area 1                                                                  0.06
# Area 2                                                                 -0.37
# Area 3                                                                  0.11
# Area 4                                                                 -0.06
# Area 5                                                                 -0.19
# Panel Data Summary Index                                               -0.13
# Standard Deviation of the 5 EFW Areas                                   1.00
# Year                                                                   -0.00
#
#                                        Year
# Area 1                                 0.05
# Area 2                                 0.02
# Area 3                                 0.24
# Area 4                                 0.08
# Area 5                                 0.20
# Panel Data Summary Index               0.16
# Standard Deviation of the 5 EFW Areas -0.00
# Year                                   1.00

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
def corr_matrix_heatmap(data, dim =20, pp = None):   
    fig, ax = plt.subplots(figsize=(dim,dim))  
    im = ax.imshow(data, norm = plt.cm.colors.Normalize(-1,1), cmap = "seismic")   
    labels = data.keys()  
    num_vars = len(labels)  
    tick_labels = [lab.replace(" ", "\n") for lab in labels]  
    tick_font_size = 120 / num_vars  
    val_font_size = 200 / num_vars  
    plt.rcParams.update({'font.size': tick_font_size}) 
    x_ticks = np.arange(num_vars)  
    # select labels and rotate them 90 degrees so that they are vertical  
    plt.xticks(x_ticks, tick_labels, fontsize = tick_font_size, rotation = 90)  
    # prepare space for label of each row  
    y_ticks = np.arange(num_vars)  
    # select labels  
    plt.yticks(y_ticks, tick_labels, fontsize = tick_font_size)  
    # show values in each tile of the heatmap  
    for i in range(len(labels)):  
        for j in range(len(labels)):  
            text = ax.text(i, j, str(round(data.values[i][j],2)),  
                           fontsize= val_font_size, ha="center",   
                           va="center", color = "w")
            print(i, labels[i],j,labels[j],data.values[i][j])
    title_font = {"fontname":"Times New Roman"}  
    plt.title("Correlation", fontsize = 50, **title_font)  
    cbar = fig.colorbar(im)
    plt.show()
    if pp != None:
        pp.savefig(fig, bbox_inches="tight")
    plt.close()
folder="Project 5 Plots"
try:
    os.mkdir(folder)
except:
    print(folder, "already exists")
    
pp=PdfPages(folder+ "/Economic Freedom Plots.pdf")
corr_data=data.corr()
corr_matrix_heatmap(corr_DF, pp=pp)
# Out:
# Project 5 Plots already exists
# 0 Year 0 Year 1.0
# 0 Year 1 Panel Data Summary Index 0.16
# 0 Year 2 Area 1 0.05
# 0 Year 3 Area 2 0.02
# 0 Year 4 Area 3 0.24
# 0 Year 5 Area 4 0.08
# 0 Year 6 Area 5 0.2
# 0 Year 7 Standard Deviation of the 5 EFW Areas -0.0
# 1 Panel Data Summary Index 0 Year 0.16
# 1 Panel Data Summary Index 1 Panel Data Summary Index 1.0
# 1 Panel Data Summary Index 2 Area 1 0.25
# 1 Panel Data Summary Index 3 Area 2 0.8
# 1 Panel Data Summary Index 4 Area 3 0.84
# 1 Panel Data Summary Index 5 Area 4 0.88
# 1 Panel Data Summary Index 6 Area 5 0.83
# 1 Panel Data Summary Index 7 Standard Deviation of the 5 EFW Areas -0.13
# 2 Area 1 0 Year 0.05
# 2 Area 1 1 Panel Data Summary Index 0.25
# 2 Area 1 2 Area 1 1.0
# 2 Area 1 3 Area 2 -0.14
# 2 Area 1 4 Area 3 0.08
# 2 Area 1 5 Area 4 0.08
# 2 Area 1 6 Area 5 0.11
# 2 Area 1 7 Standard Deviation of the 5 EFW Areas 0.06
# 3 Area 2 0 Year 0.02
# 3 Area 2 1 Panel Data Summary Index 0.8
# 3 Area 2 2 Area 1 -0.14
# 3 Area 2 3 Area 2 1.0
# 3 Area 2 4 Area 3 0.57
# 3 Area 2 5 Area 4 0.68
# 3 Area 2 6 Area 5 0.67
# 3 Area 2 7 Standard Deviation of the 5 EFW Areas -0.37
# 4 Area 3 0 Year 0.24
# 4 Area 3 1 Panel Data Summary Index 0.84
# 4 Area 3 2 Area 1 0.08
# 4 Area 3 3 Area 2 0.57
# 4 Area 3 4 Area 3 1.0
# 4 Area 3 5 Area 4 0.7
# 4 Area 3 6 Area 5 0.61
# 4 Area 3 7 Standard Deviation of the 5 EFW Areas 0.11
# 5 Area 4 0 Year 0.08
# 5 Area 4 1 Panel Data Summary Index 0.88
# 5 Area 4 2 Area 1 0.08
# 5 Area 4 3 Area 2 0.68
# 5 Area 4 4 Area 3 0.7
# 5 Area 4 5 Area 4 1.0
# 5 Area 4 6 Area 5 0.65
# 5 Area 4 7 Standard Deviation of the 5 EFW Areas -0.06
# 6 Area 5 0 Year 0.2
# 6 Area 5 1 Panel Data Summary Index 0.83
# 6 Area 5 2 Area 1 0.11
# 6 Area 5 3 Area 2 0.67
# 6 Area 5 4 Area 3 0.61
# 6 Area 5 5 Area 4 0.65
# 6 Area 5 6 Area 5 1.0
# 6 Area 5 7 Standard Deviation of the 5 EFW Areas -0.19
# 7 Standard Deviation of the 5 EFW Areas 0 Year -0.0
# 7 Standard Deviation of the 5 EFW Areas 1 Panel Data Summary Index -0.13
# 7 Standard Deviation of the 5 EFW Areas 2 Area 1 0.06
# 7 Standard Deviation of the 5 EFW Areas 3 Area 2 -0.37
# 7 Standard Deviation of the 5 EFW Areas 4 Area 3 0.11
# 7 Standard Deviation of the 5 EFW Areas 5 Area 4 -0.06
# 7 Standard Deviation of the 5 EFW Areas 6 Area 5 -0.19
# 7 Standard Deviation of the 5 EFW Areas 7 Standard Deviation of the 5 EFW Areas 1.0

# %%
mean_data = data.groupby("Year").mean()
mean_data
# Out:
#       Panel Data Summary Index    Area 1    Area 2    Area 3    Area 4  \
# Year
# 1970                  5.699777  6.115453  4.828106  7.219435  5.142756
# 1975                  5.330897  5.638449  4.704443  6.007796  4.904180
# 1980                  5.358043  5.474844  4.790720  6.094311  4.946113
# 1985                  5.423119  5.477523  4.872785  6.261684  4.982920
# 1990                  5.716292  6.061804  4.964320  6.302771  5.617330
# 1995                  6.163039  6.497296  5.199571  6.481726  6.832335
# 2000                  6.592760  6.628378  5.231726  7.598053  6.984603
# 2001                  6.599041  6.668608  5.196628  7.770338  6.982832
# 2002                  6.663490  6.662246  5.185988  7.861788  6.997352
# 2003                  6.681009  6.672367  5.166744  7.880149  7.047378
# 2004                  6.710922  6.725984  5.166447  7.951051  6.992921
# 2005                  6.736056  6.854917  5.293075  7.864794  6.883771
# 2006                  6.780060  6.846312  5.352180  7.894100  6.940902
# 2007                  6.810935  6.899178  5.387801  7.922043  6.981182
# 2008                  6.769782  6.852975  5.374990  7.764033  7.023490
# 2009                  6.774924  6.681671  5.367239  7.930318  7.020073
# 2010                  6.809513  6.650865  5.292711  8.037720  7.032564
# 2011                  6.812160  6.713350  5.295417  8.018281  7.021954
# 2012                  6.823437  6.716821  5.287927  8.111376  6.986931
# 2013                  6.820710  6.693263  5.263555  8.194170  6.965516
# 2014                  6.869996  6.679071  5.311640  8.286492  7.050601
# 2015                  6.868486  6.685504  5.344179  8.277932  7.024002
# 2016                  6.872591  6.745947  5.310897  8.315198  7.002284
# 2017                  6.840911  6.714026  5.323041  8.280965  6.994231
# 2018                  6.888338  6.748693  5.331769  8.345674  7.012747
# 2019                  6.893302  6.768514  5.312195  8.328343  7.030791
# 2020                  6.749758  6.603613  5.360975  8.242351  6.615388
#
#         Area 5  Standard Deviation of the 5 EFW Areas
# Year
# 1970  5.643092                               1.709156
# 1975  5.600009                               1.576832
# 1980  5.661589                               1.574210
# 1985  5.687262                               1.601393
# 1990  5.816249                               1.506858
# 1995  6.085262                               1.504387
# 2000  6.559508                               1.393556
# 2001  6.394464                               1.416103
# 2002  6.621917                               1.440340
# 2003  6.649483                               1.438637
# 2004  6.722156                               1.413789
# 2005  6.782237                               1.354957
# 2006  6.864784                               1.314316
# 2007  6.866936                               1.306544
# 2008  6.834730                               1.284184
# 2009  6.878410                               1.344329
# 2010  7.021393                               1.365870
# 2011  7.037927                               1.339546
# 2012  7.030441                               1.361036
# 2013  6.994317                               1.380134
# 2014  7.018232                               1.398006
# 2015  7.006872                               1.394493
# 2016  6.986641                               1.402108
# 2017  6.892610                               1.393350
# 2018  7.005562                               1.431332
# 2019  7.029122                               1.458044
# 2020  6.927039                               1.455067

# %%
plt.rcParams.update({'font.size':40})

def plot_ts_scatter(data):
    time = data.index.get_level_values("Year")
    for key, cal in data.items():
        fig, ax = pt.subplots(figsize =(20,12))
        ax.scatter(time,val,alpha=.2,color = "k", s =10)
        ax.set_tittle(key,fortsize =54)
        mean_data[key].plot(ax = ax, linewidth = 10, color = "C0")
        plt.savefig(folder+"/"+key+".jpeg")
plot_ts_scatter(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19044\3320675403.py in <module>
#       9         mean_data[key].plot(ax = ax, linewidth = 10, color = "C0")
#      10         plt.savefig(folder+"/"+key+".jpeg")
# ---> 11 plot_ts_scatter(data)
#
# ~\AppData\Local\Temp\ipykernel_19044\3320675403.py in plot_ts_scatter(data)
#       2
#       3 def plot_ts_scatter(data):
# ----> 4     time = data.index.get_level_values("Year")
#       5     for key, cal in data.items():
#       6         fig, ax = pt.subplots(figsize =(20,12))
#
# D:\python\lib\site-packages\pandas\core\indexes\base.py in _get_level_values(self, level)
#    2014         Index(['a', 'b', 'c'], dtype='object')
#    2015         """
# -> 2016         self._validate_index_level(level)
#    2017         return self
#    2018
#
# D:\python\lib\site-packages\pandas\core\indexes\base.py in _validate_index_level(self, level)
#    1937                 )
#    1938         elif level != self.name:
# -> 1939             raise KeyError(
#    1940                 f"Requested level ({level}) does not match index name ({self.name})"
#    1941             )
#
# KeyError: 'Requested level (Year) does not match index name (None)'

# %%
def color_dim_scatter(data, pp):
    for key1 in data:
        for key2 in data:
            if key1 != key2:
                for key3 in data:
                    if key1 != key3 and key2 != key3:
                        fig,ax = plt.subplots(figsize = (20,20))
                        data.plot.scatter(x = key1, y =key2, c = key3,
                                     colormap= "viridis",
                                     s =50,
                                     alpha =.7,
                                     ax=ax)
                        plt.setp(ax.get_xticklines(), visible = False)  
                        plt.setp(ax.get_yticklines(), visible = False)
                        plt.show()
                        pp.savefig(fig, bbox_inches= "tight")
                        plt.close()
color_dim_scatter(data[["Size of Government","Legal System and Property Rights","Sound Money"]],pp)
pp.close()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19044\2007659030.py in <module>
#      16                         pp.savefig(fig, bbox_inches= "tight")
#      17                         plt.close()
# ---> 18 color_dim_scatter(data[["Size of Government","Legal System and Property Rights","Sound Money"]],pp)
#      19 pp.close()
#
# D:\python\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# D:\python\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
#    5797
#    5798         keyarr = self.take(indexer)
#
# D:\python\lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    5854                 if use_interval_msg:
#    5855                     key = list(key)
# -> 5856                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5857
#    5858             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Size of Government', 'Legal System and Property Rights',\n       'Sound Money'],\n      dtype='object')] are in the [columns]"

# %%
def formatted_scatter_matrix(data, pp = None, dim=15):
    figsize = (dim,dim)
    num_vars = len(data.keys())
    fontsize = 65 / num_vars
    fig, ax = plt.subplots(figsize=figsize)
    plt.rcParams.update({'font.size':fontsize})
    pd.plotting.scatter_matrix(data,alpha = .1, ax =ax)
    
plot_data = data.rename(
    columns = {key:key.replace(" ","\n")for key in data.keys()})
formatted_scatter_matrix(plot_data, dim=15)
# Out:
# C:\Users\joeyw\AppData\Local\Temp\ipykernel_19044\986746703.py:7: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   pd.plotting.scatter_matrix(data,alpha = .1, ax =ax)

# %% [markdown]
# Create a list of random numbers between 0 and 100 whose length is 1000. (Hint: import random; search "python random" to learn more about the library.)
#
# Use the variance function from the textbook to find the variance of this list. Assume that the list represent a population in whole.
#
# Create a 9 more lists of the same length whose elements are random numbers between 0 and 100. Use a nested dictionary to house and identify these lists. Keys for the first layer should be the numbers 1 through 10. Lists should be stored using a second key as follows: dict_name[index]["list"]. Index represents the particular integer key between 1 and 10 as noted above.
#
# Find the variance of each list and store it as follows: dict_name[index]["variance"].
#
# At the end of chapter 2, we used for loops to find min and max values. Create a min() function and max() function and pass the values from the list in question 1 to each of these to determine the min and max values in that list.
#
# Explain why it might be advantageous to create a function instead of building all commands from scratch as you create a script.

# %% [markdown]
# ## #1

# %%
list1=list(range(3,306,3))
print(list1)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303]

# %% [markdown]
# ## #2

# %%
list1=list(range(3,306,3))
string1=str(list1)
print(string1)
# Out:
# [3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303]

# %% [markdown]
# ## #3

# %%
print(string1.replace(", ",""))
# Out:
# []

# %% [markdown]
# ## #4

# %%
total = 0
for i in range(300,3,-3):
    print(str(i))
# Out:
# 300
# 297
# 294
# 291
# 288
# 285
# 282
# 279
# 276
# 273
# 270
# 267
# 264
# 261
# 258
# 255
# 252
# 249
# 246
# 243
# 240
# 237
# 234
# 231
# 228
# 225
# 222
# 219
# 216
# 213
# 210
# 207
# 204
# 201
# 198
# 195
# 192
# 189
# 186
# 183
# 180
# 177
# 174
# 171
# 168
# 165
# 162
# 159
# 156
# 153
# 150
# 147
# 144
# 141
# 138
# 135
# 132
# 129
# 126
# 123
# 120
# 117
# 114
# 111
# 108
# 105
# 102
# 99
# 96
# 93
# 90
# 87
# 84
# 81
# 78
# 75
# 72
# 69
# 66
# 63
# 60
# 57
# 54
# 51
# 48
# 45
# 42
# 39
# 36
# 33
# 30
# 27
# 24
# 21
# 18
# 15
# 12
# 9
# 6

# %% [markdown]
# ## #5

# %%
list1=list(range(3,306,3))
len_list1=len(list1)

print("i","val")
for i in range(len_list1):
    print(i,list1[i])
# Out:
# i val
# 0 3
# 1 6
# 2 9
# 3 12
# 4 15
# 5 18
# 6 21
# 7 24
# 8 27
# 9 30
# 10 33
# 11 36
# 12 39
# 13 42
# 14 45
# 15 48
# 16 51
# 17 54
# 18 57
# 19 60
# 20 63
# 21 66
# 22 69
# 23 72
# 24 75
# 25 78
# 26 81
# 27 84
# 28 87
# 29 90
# 30 93
# 31 96
# 32 99
# 33 102
# 34 105
# 35 108
# 36 111
# 37 114
# 38 117
# 39 120
# 40 123
# 41 126
# 42 129
# 43 132
# 44 135
# 45 138
# 46 141
# 47 144
# 48 147
# 49 150
# 50 153
# 51 156
# 52 159
# 53 162
# 54 165
# 55 168
# 56 171
# 57 174
# 58 177
# 59 180
# 60 183
# 61 186
# 62 189
# 63 192
# 64 195
# 65 198
# 66 201
# 67 204
# 68 207
# 69 210
# 70 213
# 71 216
# 72 219
# 73 222
# 74 225
# 75 228
# 76 231
# 77 234
# 78 237
# 79 240
# 80 243
# 81 246
# 82 249
# 83 252
# 84 255
# 85 258
# 86 261
# 87 264
# 88 267
# 89 270
# 90 273
# 91 276
# 92 279
# 93 282
# 94 285
# 95 288
# 96 291
# 97 294
# 98 297
# 99 300
# 100 303

# %% [markdown]
# ## #6

# %%
list1[0:-1:2]
# Out:
# [3,
#  9,
#  15,
#  21,
#  27,
#  33,
#  39,
#  45,
#  51,
#  57,
#  63,
#  69,
#  75,
#  81,
#  87,
#  93,
#  99,
#  105,
#  111,
#  117,
#  123,
#  129,
#  135,
#  141,
#  147,
#  153,
#  159,
#  165,
#  171,
#  177,
#  183,
#  189,
#  195,
#  201,
#  207,
#  213,
#  219,
#  225,
#  231,
#  237,
#  243,
#  249,
#  255,
#  261,
#  267,
#  273,
#  279,
#  285,
#  291,
#  297]

# %% [markdown]
# ## #7

# %% [markdown]
# the difference between a dynamic list in python and a tuple is that the list is dynamic and the tuple is static characteristics
